# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/cleaning_eval.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# Input sample:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2021-07-31           258528.0           259900.0   145.396160
# 1  2021-08-31           457000.0           429000.0   253.164135
# 2  2020-02-29           187250.0           202500.0    99.965760
# 3  2020-06-30           517500.0           539900.0   217.805198
# 4  2021-07-31           749000.0           749400.0   349.226265
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        140.979244       104.0           98.0         107.0       66.0
# 1        257.973734        82.0           95.0         117.0      126.0
# 2        109.198464        94.0          115.0         140.0      157.0
# 3        217.108051         6.0           11.0          11.0       14.0
# 4        339.058053       113.0          112.0         140.0       60.0
#
#    median_dom  ...  Median Home Value  Total Labor Force  \
# 0        48.0  ...           182900.0            10937.0
# 1        71.0  ...                0.0                0.0
# 2        47.5  ...           161000.0            31265.0
# 3        68.0  ...           531100.0             1251.0
# 4        18.0  ...           591100.0            16826.0
#
#    Unemployed Population Total School Age Population  Total School Enrollment  \
# 0                  250.0                     20604.0                  20604.0
# 1                    0.0                         0.0                      0.0
# 2                 1746.0                     52357.0                  52357.0
# 3                   30.0                      1991.0                   1991.0
# 4                  681.0                     31591.0                  31591.0
#
#    Median Commute Time          price                         city_full  lat  \
# 0              10007.0  255300.562038                        cincinnati  NaN
# 1                  0.0  450603.296700       new york-newark-jersey city  NaN
# 2              27625.0  189474.969209    houston-pasadena-the woodlands  NaN
# 3               1156.0  504649.454265         baltimore-columbia-towson  NaN
# 4              14740.0  699558.033278  riverside-san bernardino-ontario  NaN
#
#    lng
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 41 columns]
# ⚠️ Skipping lat/lng merge: already present in DataFrame.
# ✅ Dropped 0 duplicate rows (excluding date/year).
# ✅ Removed 0 rows with median_list_price > 19M.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 21
#      18 display(df.head())
#      20 # Run inference
# ---> 21 preds_df = predict(df)
#      22 print("✅ Predictions returned")
#      23 display(preds_df[["predicted_price"]].head())
#
# File ~\Desktop\Paolo\VS_CODE\Regression_ML_EndtoEnd\src\inference_pipeline\inference.py:70, in predict(input_df, model_path, freq_encoder_path, target_encoder_path)
#      68 # Target encoding (city_full → city_full_encoded)
#      69 if Path(target_encoder_path).exists() and "city_full" in df.columns:
# ---> 70     target_encoder = load(target_encoder_path)
#      71     df["city_full_encoded"] = target_encoder.transform(df["city_full"])
#      72     df = df.drop(columns=["city_full"], errors="ignore")
#
# File c:\Users\User\Desktop\Paolo\VS_CODE\Regression_ML_EndtoEnd\venv\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File c:\Users\User\Desktop\Paolo\VS_CODE\Regression_ML_EndtoEnd\venv\Lib\site-packages\joblib\numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)    633             stacklevel=3,
#     634         )
#
# File ~\anaconda3\Lib\pickle.py:1255, in _Unpickler.load(self)
#    1253             raise EOFError
#    1254         assert isinstance(key, bytes_types)
# -> 1255         dispatch[key[0]](self)
#    1256 except _Stop as stopinst:
#    1257     return stopinst.value
#
# File ~\anaconda3\Lib\pickle.py:1631, in _Unpickler.load_reduce(self)
#    1629 args = stack.pop()
#    1630 func = stack[-1]
# -> 1631 stack[-1] = func(*args)
#
# TypeError: StringDtype.__init__() takes from 1 to 2 positional arguments but 3 were given
